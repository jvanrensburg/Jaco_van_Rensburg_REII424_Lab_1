# %%
#Task 1
import csv
filename = "data.csv"
f=open(filename,"r")

# %%
#Task 2
c = csv.reader(f)
i = next(c)
print(i)
# Out:
# ['Time Stamp', 'Time Zone', 'Name', 'PTID', 'Load']

# %%
#Task 3
for i in range(5):
    j = next(c)
    print(j)
# Out:
# ['01/01/2004 00:00:00', 'EST', 'CAPITL', '61757', '1015']
# ['01/01/2004 00:00:00', 'EST', 'CENTRL', '61754', '1651']
# ['01/01/2004 00:00:00', 'EST', 'DUNWOD', '61760', '618']
# ['01/01/2004 00:00:00', 'EST', 'GENESE', '61753', '972']
# ['01/01/2004 00:00:00', 'EST', 'HUD VL', '61758', '1120']

# %%
#Task 4
with open("data.csv") as g:
    reader = csv.reader(g)
    for row in reader:
        print("".join(row))
# Out:
# Time StampTime ZoneNamePTIDLoad
# 01/01/2004 00:00:00ESTCAPITL617571015
# 01/01/2004 00:00:00ESTCENTRL617541651
# 01/01/2004 00:00:00ESTDUNWOD61760618
# 01/01/2004 00:00:00ESTGENESE61753972
# 01/01/2004 00:00:00ESTHUD VL617581120
# 01/01/2004 00:00:00ESTMHK VL61756645
# 01/01/2004 00:00:00ESTMILLWD61759223
# 01/01/2004 00:00:00ESTN.Y.C._LONGIL7267
# 01/01/2004 00:00:00ESTNORTH61755622
# 01/01/2004 00:00:00ESTWEST617521591
# 01/01/2004 00:00:47ESTCAPITL617571016
# 01/01/2004 00:00:47ESTCENTRL617541653
# 01/01/2004 00:00:47ESTDUNWOD61760615
# 01/01/2004 00:00:47ESTGENESE61753985
# 01/01/2004 00:00:47ESTHUD VL617581106
# 01/01/2004 00:00:47ESTMHK VL61756641
# 01/01/2004 00:00:47ESTMILLWD61759228
# 01/01/2004 00:00:47ESTN.Y.C._LONGIL7272
# 01/01/2004 00:00:47ESTNORTH61755625
# 01/01/2004 00:00:47ESTWEST617521609
# 01/01/2004 00:01:47ESTCAPITL617571021
# 01/01/2004 00:01:47ESTCENTRL617541647
# 01/01/2004 00:01:47ESTDUNWOD61760618
# 01/01/2004 00:01:47ESTGENESE61753980
# ...
