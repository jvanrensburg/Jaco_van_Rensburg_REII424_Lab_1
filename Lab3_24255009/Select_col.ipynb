# %%
import csv
filename = "data.csv"
fl=open(filename,"r")
users_dict = {}
with open('reduced.csv', 'wb') as f:
    writer = csv.writer(f)
    with open('data.csv', 'r') as csvfile:
        reader = csv.DictReader(csvfile, delimiter = ',')
        for row in reader:
            j = row['Time Stamp'], row['Name'], row['Load']
            print(j)
            
fl.close()
# Out:
# ('01/01/2004 00:00:00', 'CAPITL', '1015')
# ('01/01/2004 00:00:00', 'CENTRL', '1651')
# ('01/01/2004 00:00:00', 'DUNWOD', '618')
# ('01/01/2004 00:00:00', 'GENESE', '972')
# ('01/01/2004 00:00:00', 'HUD VL', '1120')
# ('01/01/2004 00:00:00', 'MHK VL', '645')
# ('01/01/2004 00:00:00', 'MILLWD', '223')
# ('01/01/2004 00:00:00', 'N.Y.C._LONGIL', '7267')
# ('01/01/2004 00:00:00', 'NORTH', '622')
# ('01/01/2004 00:00:00', 'WEST', '1591')
# ('01/01/2004 00:00:47', 'CAPITL', '1016')
# ('01/01/2004 00:00:47', 'CENTRL', '1653')
# ('01/01/2004 00:00:47', 'DUNWOD', '615')
# ('01/01/2004 00:00:47', 'GENESE', '985')
# ('01/01/2004 00:00:47', 'HUD VL', '1106')
# ('01/01/2004 00:00:47', 'MHK VL', '641')
# ('01/01/2004 00:00:47', 'MILLWD', '228')
# ('01/01/2004 00:00:47', 'N.Y.C._LONGIL', '7272')
# ('01/01/2004 00:00:47', 'NORTH', '625')
# ('01/01/2004 00:00:47', 'WEST', '1609')
# ('01/01/2004 00:01:47', 'CAPITL', '1021')
# ('01/01/2004 00:01:47', 'CENTRL', '1647')
# ...
